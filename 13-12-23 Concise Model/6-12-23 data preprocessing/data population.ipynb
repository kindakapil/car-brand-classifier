# %%
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
import keras.utils as image
# Out:
# 2023-12-07 01:41:53.874142: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-07 01:41:53.905882: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-07 01:41:54.054223: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-07 01:41:54.054271: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
car_folder = 'Toyota'
multiplier = 1

from os import listdir
img_list = listdir(f'Base Dataset/{car_folder}')

img_list
# Out:
# ['frontfacingToyotacar154.jpeg',
#  'frontfacingToyotacar263.jpeg',
#  'frontfacingToyotacar371.jpeg',
#  'frontfacingToyotacar211.jpeg',
#  'frontfacingToyotacar182.jpeg',
#  'frontfacingToyotacar25.jpeg',
#  'frontfacingToyotacar141.jpeg',
#  'frontfacingToyotacar295.jpeg',
#  'frontfacingToyotacar578.jpeg',
#  'frontfacingToyotacar85.jpeg',
#  'frontfacingToyotacar113.jpeg',
#  'frontfacingToyotacar292.jpeg',
#  'frontfacingToyotacar108.jpeg',
#  'frontfacingToyotacar255.jpeg',
#  'frontfacingToyotacar105.jpeg',
#  'frontfacingToyotacar0.jpeg',
#  'frontfacingToyotacar563.jpeg',
#  'frontfacingToyotacar622.jpeg',
#  'frontfacingToyotacar103.jpeg',
#  'frontfacingToyotacar396.jpeg',
#  'frontfacingToyotacar117.jpeg',
#  'frontfacingToyotacar345.jpeg',
#  'frontfacingToyotacar161.jpeg',
#  'frontfacingToyotacar286.jpeg',
#  'frontfacingToyotacar89.jpeg',
#  'frontfacingToyotacar602.jpeg',
#  'frontfacingToyotacar9.jpeg',
#  'frontfacingToyotacar526.jpeg',
# ...

# %%
datagen = ImageDataGenerator(rescale = 1./255,
                                  #  shear_range = 0.2,
                                   zoom_range = 0.3,
                                   rotation_range = 10, #
                                 #   width_shift_range = 0.1,
                                 #   height_shift_range = 0.1
                                #    validation_split = 0.3,
                                #    horizontal_flip = False
)

for i in img_list:
    image_name = i
    print(image_name)
    img = image.load_img(f'Base Dataset/{car_folder}/{image_name}',target_size = (224,224))
    img = image.img_to_array(img)
    input_batch = img.reshape(1,224,224,3)
    i = 0
    for output in datagen.flow(input_batch, batch_size=1,save_to_dir=f'augmented images/{car_folder}'):
        i = i+1
        if i == multiplier:
            break
# Out:
# frontfacingToyotacar154.jpeg
# frontfacingToyotacar263.jpeg
# frontfacingToyotacar371.jpeg
# frontfacingToyotacar211.jpeg
# frontfacingToyotacar182.jpeg
# frontfacingToyotacar25.jpeg
# frontfacingToyotacar141.jpeg
# frontfacingToyotacar295.jpeg
# frontfacingToyotacar578.jpeg
# frontfacingToyotacar85.jpeg
# frontfacingToyotacar113.jpeg
# frontfacingToyotacar292.jpeg
# frontfacingToyotacar108.jpeg
# frontfacingToyotacar255.jpeg
# frontfacingToyotacar105.jpeg
# frontfacingToyotacar0.jpeg
# frontfacingToyotacar563.jpeg
# frontfacingToyotacar622.jpeg
# frontfacingToyotacar103.jpeg
# frontfacingToyotacar396.jpeg
# frontfacingToyotacar117.jpeg
# frontfacingToyotacar345.jpeg
# frontfacingToyotacar161.jpeg
# frontfacingToyotacar286.jpeg
# frontfacingToyotacar89.jpeg
# frontfacingToyotacar602.jpeg
# frontfacingToyotacar9.jpeg
# frontfacingToyotacar526.jpeg
# frontfacingToyotacar402.jpeg
# frontfacingToyotacar465.jpeg
# frontfacingToyotacar207.jpeg
# frontfacingToyotacar2.jpeg
# ...

# %%
###DON'T RUN FROM HERE. ONLY ROUGHWORK


img = image.load_img('train/Ford/frontfacingFordcar169.jpeg',target_size = (224,224))
# img = image.load_img(f'{image_name}.jpg',target_size = (224,224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
datagen = ImageDataGenerator(rescale = 1./255,
                                  #  shear_range = 0.2,
                                   zoom_range = 0.3,
                                   rotation_range = 10, #
                                 #   width_shift_range = 0.1,
                                 #   height_shift_range = 0.1
                                #    validation_split = 0.3,
                                #    horizontal_flip = False
)

# %%
# from keras.preprocessing.image import ImageDataGenerator

img = image.img_to_array(img)

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
input_batch = img.reshape(1,224,224,3)

# %%
i = 0
for output in datagen.flow(input_batch, batch_size=1,save_to_dir='augmentated images'):
    i = i+1
    if i == 10:
        break
